# %% [markdown]
# # O que é o Pandas?

# %% [markdown]
# Resposta simples: Excel pra Python, só que melhor.
#
# ![Pandas Logo](https://pandas.pydata.org/_static/pandas_logo.png)

# %% [markdown]
# Obs: O nome Pandas não tem nada a ver com o urso panda, mas sim com o termo "PANel DAta Structures", da econometria.

# %% [markdown]
# ## Importando o pandas
#
# Convenção \#1: Você sempre verá o pandas sendo importado desta maneira

# %%
import pandas as pd

# %% [markdown]
# ## Read/Write

# %% [markdown]
# Convenção \#2:
# * Read:
#    * `pd.read_csv` ou `pd.read_excel` ou `pd.read_json` ou ...
# * Write:
#    * `pd.write_csv` ou `pd.write_excel` ou `pd.write_json` ou ...

# %%
df_salary = pd.read_csv('../DATA/baseballdatabank-2017.1/core/Salaries.csv')

# %% [markdown]
# ## Preview

# %%
df_salary.head()
# Out:
#    yearID teamID lgID   playerID  salary
# 0    1985    ATL   NL  barkele01  870000
# 1    1985    ATL   NL  bedrost01  550000
# 2    1985    ATL   NL  benedbr01  545000
# 3    1985    ATL   NL   campri01  633333
# 4    1985    ATL   NL  ceronri01  625000

# %%
df_salary.tail()
# Out:
#        yearID teamID lgID   playerID    salary
# 26423    2016    WSN   NL  strasst01  10400000
# 26424    2016    WSN   NL  taylomi02    524000
# 26425    2016    WSN   NL  treinbl01    524900
# 26426    2016    WSN   NL  werthja01  21733615
# 26427    2016    WSN   NL  zimmery01  14000000

# %%
df_salary.head(10)
# Out:
#    yearID teamID lgID   playerID  salary
# 0    1985    ATL   NL  barkele01  870000
# 1    1985    ATL   NL  bedrost01  550000
# 2    1985    ATL   NL  benedbr01  545000
# 3    1985    ATL   NL   campri01  633333
# 4    1985    ATL   NL  ceronri01  625000
# 5    1985    ATL   NL  chambch01  800000
# 6    1985    ATL   NL  dedmoje01  150000
# 7    1985    ATL   NL  forstte01  483333
# 8    1985    ATL   NL  garbege01  772000
# 9    1985    ATL   NL  harpete01  250000

# %%
df_salary
# Out:
#        yearID teamID lgID   playerID    salary
# 0        1985    ATL   NL  barkele01    870000
# 1        1985    ATL   NL  bedrost01    550000
# 2        1985    ATL   NL  benedbr01    545000
# 3        1985    ATL   NL   campri01    633333
# 4        1985    ATL   NL  ceronri01    625000
# 5        1985    ATL   NL  chambch01    800000
# 6        1985    ATL   NL  dedmoje01    150000
# 7        1985    ATL   NL  forstte01    483333
# 8        1985    ATL   NL  garbege01    772000
# 9        1985    ATL   NL  harpete01    250000
# 10       1985    ATL   NL  hornebo01   1500000
# 11       1985    ATL   NL  hubbagl01    455000
# 12       1985    ATL   NL  mahleri01    407500
# 13       1985    ATL   NL  mcmurcr01    275000
# 14       1985    ATL   NL  mumphje01    775000
# 15       1985    ATL   NL  murphda05   1625000
# 16       1985    ATL   NL  oberkke01    616667
# 17       1985    ATL   NL  perezpa01    450000
# 18       1985    ATL   NL  perryge01    120000
# ...

# %%
df_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26428 entries, 0 to 26427
# Data columns (total 5 columns):
# yearID      26428 non-null int64
# teamID      26428 non-null object
# lgID        26428 non-null object
# playerID    26428 non-null object
# salary      26428 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 1.0+ MB

# %%
df_salary.describe()
# Out:
#              yearID        salary
# count  26428.000000  2.642800e+04
# mean    2000.878727  2.085634e+06
# std        8.909314  3.455348e+06
# min     1985.000000  0.000000e+00
# 25%     1994.000000  2.947020e+05
# 50%     2001.000000  5.500000e+05
# 75%     2009.000000  2.350000e+06
# max     2016.000000  3.300000e+07

# %%
df_salary['salary'].max()
# Out:
# 33000000

# %% [markdown]
# ## Dataframes

# %%
df1 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Int_rate':[2, 3, 2, 2],
                    'US_GDP_Thousands':[50, 55, 65, 55]},
                   index = [2001, 2002, 2003, 2004])

# %%
df1.head()
# Out:
#       HPI  Int_rate  US_GDP_Thousands
# 2001   80         2                50
# 2002   85         3                55
# 2003   88         2                65
# 2004   85         2                55

# %%
import numpy as np

df = pd.DataFrame(np.random.randn(80, 5), columns=list('ABCDE'))

# %%
df.head()
# Out:
#           A         B         C         D         E
# 0  0.841553 -0.042350 -0.799797  1.043253  0.165075
# 1 -1.224229  1.575821 -1.191911 -1.211059  1.047726
# 2 -1.435529  0.756218 -1.284260 -0.241947 -0.804241
# 3  1.387524  0.171766 -1.836581 -1.167904  0.117754
# 4 -1.819807 -1.696339  1.145354 -1.467172 -0.295802

# %%
df[2:4]
# Out:
#           A         B         C         D         E
# 2 -1.435529  0.756218 -1.284260 -0.241947 -0.804241
# 3  1.387524  0.171766 -1.836581 -1.167904  0.117754

# %%
df.iloc[2:4]
# Out:
#           A         B         C         D         E
# 2 -1.435529  0.756218 -1.284260 -0.241947 -0.804241
# 3  1.387524  0.171766 -1.836581 -1.167904  0.117754

# %%
df.iloc[2:4, :2]
# Out:
#           A         B
# 2 -1.435529  0.756218
# 3  1.387524  0.171766

# %%
df.loc[2:4, 'A':'D']
# Out:
#           A         B         C         D
# 2 -1.435529  0.756218 -1.284260 -0.241947
# 3  1.387524  0.171766 -1.836581 -1.167904
# 4 -1.819807 -1.696339  1.145354 -1.467172

# %%
df.index = ["Index:{}".format(x) for x in df.index]

# %%
df.head()
# Out:
#                 A         B         C         D         E
# Index:0  0.841553 -0.042350 -0.799797  1.043253  0.165075
# Index:1 -1.224229  1.575821 -1.191911 -1.211059  1.047726
# Index:2 -1.435529  0.756218 -1.284260 -0.241947 -0.804241
# Index:3  1.387524  0.171766 -1.836581 -1.167904  0.117754
# Index:4 -1.819807 -1.696339  1.145354 -1.467172 -0.295802

# %%
df.set_index('A')
# Out:
#                   B         C         D         E
# A
#  0.841553 -0.042350 -0.799797  1.043253  0.165075
# -1.224229  1.575821 -1.191911 -1.211059  1.047726
# -1.435529  0.756218 -1.284260 -0.241947 -0.804241
#  1.387524  0.171766 -1.836581 -1.167904  0.117754
# -1.819807 -1.696339  1.145354 -1.467172 -0.295802
# -0.591620  0.010819  0.010618  0.191430  1.411943
#  1.267730 -1.098734 -0.224477  0.055646 -0.170374
# -0.479657 -0.664202 -1.424679 -0.194301 -0.026275
#  0.092516 -0.749059  0.535622  0.290033  0.042626
# -0.195560  1.060348 -0.238433 -0.624775 -1.169054
# -0.458077 -1.178573  0.736857  0.214172  0.907777
#  0.478711 -0.447756 -0.084252  0.807260 -1.643497
#  1.358796 -0.880945 -1.181895 -1.477563 -0.367863
# -0.372435 -0.324635  0.571848 -0.451481  0.873458
#  0.324305  0.505357 -0.057755 -0.037061 -1.055061
#  0.790021 -0.105548  0.012142  1.060314 -0.333221
# -0.277351 -1.035858  0.018472 -0.939242  1.808456
#  1.499366  0.629404  0.734574 -0.425066  1.731417
# ...

# %%
df.set_index('A', inplace=True)
df.head()
# Out:
#                   B         C         D         E
# A
#  0.841553 -0.042350 -0.799797  1.043253  0.165075
# -1.224229  1.575821 -1.191911 -1.211059  1.047726
# -1.435529  0.756218 -1.284260 -0.241947 -0.804241
#  1.387524  0.171766 -1.836581 -1.167904  0.117754
# -1.819807 -1.696339  1.145354 -1.467172 -0.295802

# %% [markdown]
# ## Datas

# %%
df_homegames = pd.read_csv('../DATA/baseballdatabank-2017.1/core/HomeGames.csv')

# %%
df_homegames.head()
# Out:
#    year.key league.key team.key park.key  span.first   span.last  games  \
# 0      1871        NaN      BS1    BOS01  1871-05-16  1871-10-07     16
# 1      1871        NaN      BS1    NYC01  1871-05-27  1871-05-27      1
# 2      1871        NaN      CH1    CHI01  1871-05-08  1871-09-29     16
# 3      1871        NaN      CH1    NYC01  1871-10-30  1871-10-30      1
# 4      1871        NaN      CL1    CIN01  1871-05-13  1871-07-22      2
#
#    openings  attendance
# 0        16       32600
# 1         1        3000
# 2        15       85500
# 3         1         600
# 4         2        2200

# %%
df_homegames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3006 entries, 0 to 3005
# Data columns (total 9 columns):
# year.key      3006 non-null int64
# league.key    2929 non-null object
# team.key      3006 non-null object
# park.key      3006 non-null object
# span.first    3006 non-null object
# span.last     3006 non-null object
# games         3006 non-null int64
# openings      3006 non-null int64
# attendance    3006 non-null int64
# dtypes: int64(4), object(5)
# memory usage: 211.4+ KB

# %%
df_homegames = pd.read_csv('../DATA/baseballdatabank-2017.1/core/HomeGames.csv', parse_dates=['span.first', 'span.last'])

# %%
dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')

df_homegames = pd.read_csv('../DATA/baseballdatabank-2017.1/core/HomeGames.csv', parse_dates=['span.first', 'span.last'], date_parser=dateparse)

# %%
df_homegames.head()
# Out:
#    year.key league.key team.key park.key span.first  span.last  games  \
# 0      1871        NaN      BS1    BOS01 1871-05-16 1871-10-07     16
# 1      1871        NaN      BS1    NYC01 1871-05-27 1871-05-27      1
# 2      1871        NaN      CH1    CHI01 1871-05-08 1871-09-29     16
# 3      1871        NaN      CH1    NYC01 1871-10-30 1871-10-30      1
# 4      1871        NaN      CL1    CIN01 1871-05-13 1871-07-22      2
#
#    openings  attendance
# 0        16       32600
# 1         1        3000
# 2        15       85500
# 3         1         600
# 4         2        2200

# %%
df_homegames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3006 entries, 0 to 3005
# Data columns (total 9 columns):
# year.key      3006 non-null int64
# league.key    2929 non-null object
# team.key      3006 non-null object
# park.key      3006 non-null object
# span.first    3006 non-null datetime64[ns]
# span.last     3006 non-null datetime64[ns]
# games         3006 non-null int64
# openings      3006 non-null int64
# attendance    3006 non-null int64
# dtypes: datetime64[ns](2), int64(4), object(3)
# memory usage: 211.4+ KB

# %% [markdown]
# ## Manipulando colunas

# %%
salary = df_salary['playerID']
salary.head()
# Out:
# 0    barkele01
# 1    bedrost01
# 2    benedbr01
# 3     campri01
# 4    ceronri01
# Name: playerID, dtype: object

# %%
# Criando uma nova coluna 
# Aplicando uma função em toda uma coluna
df_salary['Salary_sqrd'] = df_salary['salary'].apply(lambda x: x**2)

# %%
df_salary.head()
# Out:
#    yearID teamID lgID   playerID  salary   Salary_sqrd
# 0    1985    ATL   NL  barkele01  870000  756900000000
# 1    1985    ATL   NL  bedrost01  550000  302500000000
# 2    1985    ATL   NL  benedbr01  545000  297025000000
# 3    1985    ATL   NL   campri01  633333  401110688889
# 4    1985    ATL   NL  ceronri01  625000  390625000000

# %%
df_salary.drop(['Salary_sqrd'], axis=1)
# Out:
#        yearID teamID lgID   playerID    salary
# 0        1985    ATL   NL  barkele01    870000
# 1        1985    ATL   NL  bedrost01    550000
# 2        1985    ATL   NL  benedbr01    545000
# 3        1985    ATL   NL   campri01    633333
# 4        1985    ATL   NL  ceronri01    625000
# 5        1985    ATL   NL  chambch01    800000
# 6        1985    ATL   NL  dedmoje01    150000
# 7        1985    ATL   NL  forstte01    483333
# 8        1985    ATL   NL  garbege01    772000
# 9        1985    ATL   NL  harpete01    250000
# 10       1985    ATL   NL  hornebo01   1500000
# 11       1985    ATL   NL  hubbagl01    455000
# 12       1985    ATL   NL  mahleri01    407500
# 13       1985    ATL   NL  mcmurcr01    275000
# 14       1985    ATL   NL  mumphje01    775000
# 15       1985    ATL   NL  murphda05   1625000
# 16       1985    ATL   NL  oberkke01    616667
# 17       1985    ATL   NL  perezpa01    450000
# 18       1985    ATL   NL  perryge01    120000
# ...

# %%
df_salary.head()
# Out:
#    yearID teamID lgID   playerID  salary   Salary_sqrd
# 0    1985    ATL   NL  barkele01  870000  756900000000
# 1    1985    ATL   NL  bedrost01  550000  302500000000
# 2    1985    ATL   NL  benedbr01  545000  297025000000
# 3    1985    ATL   NL   campri01  633333  401110688889
# 4    1985    ATL   NL  ceronri01  625000  390625000000

# %%
df_salary.drop(columns=['Salary_sqrd']).head()
# Out:
#    yearID teamID lgID   playerID  salary
# 0    1985    ATL   NL  barkele01  870000
# 1    1985    ATL   NL  bedrost01  550000
# 2    1985    ATL   NL  benedbr01  545000
# 3    1985    ATL   NL   campri01  633333
# 4    1985    ATL   NL  ceronri01  625000

# %%
df_salary.drop(['Salary_sqrd'], axis=1, inplace=True)

# %%
df_salary.head()
# Out:
#    yearID teamID lgID   playerID  salary
# 0    1985    ATL   NL  barkele01  870000
# 1    1985    ATL   NL  bedrost01  550000
# 2    1985    ATL   NL  benedbr01  545000
# 3    1985    ATL   NL   campri01  633333
# 4    1985    ATL   NL  ceronri01  625000

# %%
df_salary.drop(0).head()
# Out:
#    yearID teamID lgID   playerID  salary
# 1    1985    ATL   NL  bedrost01  550000
# 2    1985    ATL   NL  benedbr01  545000
# 3    1985    ATL   NL   campri01  633333
# 4    1985    ATL   NL  ceronri01  625000
# 5    1985    ATL   NL  chambch01  800000

# %% [markdown]
# ## Groupby

# %%
df_salary.groupby(['salary'])['playerID', 'teamID', 'yearID'].max()
# Out:
#            playerID teamID  yearID
# salary
# 0         martija02    PIT    1999
# 10900     silveda01    NYA    1993
# 50000      penaal01    FLO    1997
# 60000      yettri01    TOR    1986
# 61500     sebrabo01    MON    1986
# 62000     powelde01    LAN    1986
# 62500     youngge02    TOR    1989
# 63500     santibe01    SDN    1988
# 64000     gumpeda01    SEA    1986
# 64500      reedjo01    BOS    1988
# 65000     wojnaed01    SLN    1988
# 65500     renteri01    SEA    1988
# 66000     reynoro02    PIT    1988
# 66500     starkma01    TOR    1988
# 67000     polidgu01    PIT    1988
# 67500      yettri01    PIT    1988
# 68000     zeileto01    TOR    1989
# 68500     vonohda01    LAN    1986
# 68750     swindgr01    CLE    1987
# 69000     searcst01    NYN    1989
# 70000     youmafl01    TEX    1989
# 70500     sanchis01    OAK    1989
# 71000     quintca01    PHI    1989
# 71500     masonro01    TOR    1989
# 71600     preslji01    SEA    1985
# ...

# %% [markdown]
# ## Seleções com condicionais

# %%
df_salary['playerID'] == 'barkele01'
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 26398    False
# 26399    False
# 26400    False
# 26401    False
# 26402    False
# 26403    False
# 26404    False
# 26405    False
# 26406    False
# 26407    False
# 26408    False
# 26409    False
# 26410    False
# 26411    False
# 26412    False
# 26413    False
# 26414    False
# 26415    False
# 26416    False
# 26417    False
# 26418    False
# 26419    False
# 26420    False
# 26421    False
# 26422    False
# 26423    False
# 26424    False
# ...

# %%
df_salary[df_salary['playerID'] == 'barkele01']
# Out:
#       yearID teamID lgID   playerID  salary
# 0       1985    ATL   NL  barkele01  870000
# 552     1986    ATL   NL  barkele01  880000
# 1291    1987    ATL   NL  barkele01  890000
# 1613    1987    ML4   AL  barkele01   72500
# 1917    1988    ATL   NL  barkele01  900000

# %%
df_salary[df_salary['salary'] > 30000000]['playerID']
# Out:
# 20286    rodrial01
# 21109    rodrial01
# 21945    rodrial01
# 25131    kershcl01
# 25588    greinza01
# 25965    kershcl01
# Name: playerID, dtype: object

# %%
df_salary[df_salary['salary'] > 30000000]['playerID'].unique()
# Out:
# array(['rodrial01', 'kershcl01', 'greinza01'], dtype=object)

# %%
df_salary['salary'].map(int).head()
# Out:
# 0    870000
# 1    550000
# 2    545000
# 3    633333
# 4    625000
# Name: salary, dtype: int64

# %% [markdown]
# ## Series

# %%
dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')

bitcoin_preco = pd.read_csv('../DATA/bitcoin/bitcoin.csv', parse_dates=['Date'], date_parser=dateparse)

# %%
bitcoin_preco.tail()
# Out:
#            Date    Open    High     Low   Close  Volume (BTC)  \
# 1414 2017-11-21  8220.8  8350.0  7785.4  8113.1   4807.606197
# 1415 2017-11-22  8100.8  8300.0  8025.4  8250.6   2821.816015
# 1416 2017-11-23  8251.5  8290.0  8030.0  8030.0   3096.817175
# 1417 2017-11-24  8028.7  8277.7  7850.0  8173.1   4049.820224
# 1418 2017-11-25  8174.1  8174.1  8123.9  8123.9      3.619693
#
#       Volume (Currency)  Weighted Price
# 1414       3.902334e+07     8117.000752
# 1415       2.314797e+07     8203.215967
# 1416       2.526042e+07     8156.897201
# 1417       3.263809e+07     8059.146344
# 1418       2.942308e+04     8128.611697

# %%
bitcoin_preco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1419 entries, 0 to 1418
# Data columns (total 8 columns):
# Date                 1419 non-null datetime64[ns]
# Open                 1419 non-null float64
# High                 1419 non-null float64
# Low                  1419 non-null float64
# Close                1419 non-null float64
# Volume (BTC)         1419 non-null float64
# Volume (Currency)    1419 non-null float64
# Weighted Price       1419 non-null float64
# dtypes: datetime64[ns](1), float64(7)
# memory usage: 88.8 KB

# %%
bitcoin_preco = bitcoin_preco.set_index('Date')

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
bitcoin_preco['Close'].plot(figsize=(16,8))

# %%
# https://en.wikipedia.org/wiki/Bollinger_Bands
def plot_boll_band(df, k=2, period=20):
    fig, ax = plt.subplots(figsize=(16,8))
    
    df_period_mean = df['Close'].rolling(window=period).mean()
    
    df_upper = df_period_mean + k*(df['Close'].rolling(period).std())
    
    df_lower = df_period_mean - k*(df['Close'].rolling(period).std())
    
    df['Close'].plot(ax=ax)
    df_period_mean.plot(ax=ax)
    df_upper.plot(ax=ax)
    df_lower.plot(ax=ax)
    
    return ax

# %%
plot_boll_band(bitcoin_preco.tail(220))

# %%
from bokeh.layouts import gridplot
from bokeh.plotting import figure, show, output_file

# %%
output_file('bitcoin.html')
